# %%
import os
from dotenv import load_dotenv
import json
load_dotenv()
groq_api_key = os.getenv("GROQ_API_KEY")

# %%
import os
from langchain_groq import ChatGroq
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain


llm_meal = ChatGroq(model_name="llama3-8b-8192", groq_api_key=groq_api_key)

prompt_template_meal = PromptTemplate(
    input_variables=['age', 'weight', 'height', 'veg_or_nonveg', 'disease', 'region', 'allergics'],
    template='''You are a meal planning assistant. Generate a structured 7-day meal plan in JSON format based on the user's details:
    
    - Age: {age}
    - Weight: {weight}
    - Height: {height}
    - Dietary Preference: {veg_or_nonveg}
    - Health Conditions: {disease}
    - Region: {region}
    - Allergies: {allergics}

    The JSON output should be structured like this:
    {{
      "Monday": {{
        "Breakfast": [{{"meal": "Meal Name", "nutritional_value": "Calories, Proteins, etc."}}],
        "Lunch": [{{"meal": "Meal Name", "nutritional_value": "Calories, Proteins, etc."}}],
        "Dinner": [{{"meal": "Meal Name", "nutritional_value": "Calories, Proteins, etc."}}]
      }},
      "Tuesday": {{ ... }},
      ...
      "Sunday": {{ ... }}
    }}

    Ensure all values are correctly formatted and realistic.
    and make sure that eggs are considered non-veg.
    '''
)

# %%
def get_meal_plan(age, weight, height, veg_or_nonveg, disease, region, allergics):
    """
    Fetches a personalized meal plan based on user health data using Groq API.
    """
    chain_meal = LLMChain(llm=llm_meal, prompt=prompt_template_meal)

    input_data = {
        'age': age,
        'weight': weight,
        'height': height,
        'veg_or_nonveg': veg_or_nonveg,
        'disease': disease,
        'region': region,
        'allergics': allergics
    }

    results = chain_meal.run(input_data)
    
    return results

# %%
# Example Input
meal_plan = get_meal_plan(
    age=25,
    weight=70,
    height=175,
    veg_or_nonveg="veg",
    disease="pcos",
    region="Indian",
    allergics="peanuts"
)

print("Personalized Meal Plan:\n")
print(meal_plan)
# Out:
# Personalized Meal Plan:
#
# Based on the provided details, I've generated a 7-day meal plan in JSON format. Since the user is veg, I've excluded eggs from the meal plan. Also, I've ensured that the nutritional values are realistic and meet the user's dietary requirements.
#
# Here is the JSON output:
#
# ```
# {
#   "Monday": {
#     "Breakfast": [
#       {"meal": "Oatmeal with Almonds and Fruit", "nutritional_value": "350 Calories, 8g Protein, 12g Fat, 50g Carbs"}
#     ],
#     "Lunch": [
#       {"meal": "Chickpea and Spinach Salad with Whole Wheat Bread", "nutritional_value": "450 Calories, 20g Protein, 10g Fat, 60g Carbs"}
#     ],
#     "Dinner": [
#       {"meal": "Vegetable Biryani with Raita", "nutritional_value": "500 Calories, 15g Protein, 20g Fat, 70g Carbs"}
#     ]
#   },
#   "Tuesday": {
#     "Breakfast": [
#       {"meal": "Avocado Toast with Tomato and Sprouts", "nutritional_value": "320 Calories, 5g Protein, 15g Fat, 30g Carbs"}
#     ],
#     "Lunch": [
#       {"meal": "Brown Rice and Lentil Bowl with Steamed Vegetables", "nutritional_value": "500 Calories, 20g Protein, 10g Fat, 70g Carbs"}
#     ],
#     "Dinner": [
#       {"meal": "Roasted Vegetable Quinoa Bowl with Chickpea Curry", "nutritional_value": "550 Calories, 15g Protein, 20g Fat, 80g Carbs"}
#     ]
#   },
#   "Wednesday": {
#     "Breakfast": [
#       {"meal": "Smoothie Bowl with Banana, Spinach, and Almond Milk", "nutritional_value": "300 Calories, 10g Protein, 10g Fat, 40g Carbs"}
#     ],
#     "Lunch": [
#       {"meal": "Whole Wheat Pita with Hummus, Cucumber, and Tomato", "nutritional_value": "400 Calories, 15g Protein, 15g Fat, 60g Carbs"}
#     ],
#     "Dinner": [
#       {"meal": "Vegetable and Bean Chili with Whole Wheat Crackers", "nutritional_value": "550 Calories, 20g Protein, 20g Fat, 80g Carbs"}
#     ]
#   },
#   "Thursday": {
#     "Breakfast": [
#       {"meal": "Whole Wheat Waffles with Fresh Berries and Coconut Cream", "nutritional_value": "350 Calories, 8g Protein, 15g Fat, 50g Carbs"}
#     ],
#     "Lunch": [
#       {"meal": "Grilled Vegetable Wrap with Tofu and Whole Wheat Tortilla", "nutritional_value": "500 Calories, 20g Protein, 15g Fat, 70g Carbs"}
#     ],
#     "Dinner": [
#       {"meal": "Vegetable and Mushroom Stir-Fry with Brown Rice", "nutritional_value": "500 Calories, 15g Protein, 20g Fat, 70g Carbs"}
#     ]
#   },
#   "Friday": {
#     "Breakfast": [
#       {"meal": "Green Smoothie with Banana, Spinach, and Coconut Water", "nutritional_value": "250 Calories, 10g Protein, 5g Fat, 30g Carbs"}
#     ],
#     "Lunch": [
#       {"meal": "Lentil Soup with Whole Wheat Bread and a Side Salad", "nutritional_value": "500 Calories, 20g Protein, 15g Fat, 70g Carbs"}
#     ],
#     "Dinner": [
#       {"meal": "Grilled Vegetable and Quinoa Bowl with Lemon-Tahini Sauce", "nutritional_value": "550 Calories, 15g Protein, 20g Fat, 80g Carbs"}
#     ]
#   },
#   "Saturday": {
#     "Breakfast": [
#       {"meal": "Omelette with Spinach, Mushroom, and Whole Wheat Toast", "nutritional_value": "300 Calories, 15g Protein, 10g Fat, 30g Carbs"}
#     ],
#     "Lunch": [
#       {"meal": "Chickpea and Quinoa Bowl with Roasted Vegetables", "nutritional_value": "500 Calories, 20g Protein, 15g Fat, 70g Carbs"}
#     ],
#     "Dinner": [
#       {"meal": "Vegetable and Bean Casserole with Whole Wheat Crust", "nutritional_value": "550 Calories, 20g Protein, 20g Fat, 80g Carbs"}
#     ]
#   },
#   "Sunday": {
#     "Breakfast": [
#       {"meal": "Whole Wheat Pancakes with Fresh Berries and Coconut Whipped Cream", "nutritional_value": "350 Calories, 8g Protein, 15g Fat, 50g Carbs"}
#     ],
#     "Lunch": [
#       {"meal": "Grilled Vegetable and Hummus Wrap with Whole Wheat Tortilla", "nutritional_value": "500 Calories, 20g Protein, 15g Fat, 70g Carbs"}
#     ],
#     "Dinner": [
#       {"meal": "Vegetable and Mushroom Curry with Brown Rice and Naan", "nutritional_value": "550 Calories, 15g Protein, 20g Fat, 80g Carbs"}
#     ]
#   }
# }
# ```
#
# This meal plan is designed to meet the user's dietary requirements, considering their age, weight, height, and health conditions (PCOS). It excludes peanuts as per the allergy mentioned. Each meal is approximately 500-550 calories, with a balance of protein, fat, and carbohydrates. The meals are also rich in fiber and other essential nutrients. Please note that this is a general meal plan and may need to be adjusted based on individual caloric needs and other health factors.

# %%
meal_plan = get_meal_plan(
    age=25,
    weight=70,
    height=175,
    veg_or_nonveg="veg",
    disease="none",
    region="Indian",
    allergics="peanuts"
)

print(json.dumps(meal_plan, indent=2))  # Pretty-print JSON
# Out:
# "Here is a 7-day meal plan for a 25-year-old, 70 kg, 175 cm tall individual who follows a veg diet with no health conditions, does not consume peanuts, and is from India:\n\n```json\n{\n  \"Monday\": {\n    \"Breakfast\": [\n      {\n        \"meal\": \"Oatmeal with fruits and nuts\",\n        \"nutritional_value\": \"400 calories, 10g protein, 10g fat, 60g carbohydrates\"\n      }\n    ],\n    \"Lunch\": [\n      {\n        \"meal\": \"Veggie sandwich with avocado and mixed greens\",\n        \"nutritional_value\": \"550 calories, 15g protein, 10g fat, 70g carbohydrates\"\n      }\n    ],\n    \"Dinner\": [\n      {\n        \"meal\": \"Chana masala with brown rice and mixed vegetables\",\n        \"nutritional_value\": \"600 calories, 20g protein, 15g fat, 80g carbohydrates\"\n      }\n    ]\n  },\n  \"Tuesday\": {\n    \"Breakfast\": [\n      {\n        \"meal\": \"Whole wheat toast with hummus and banana\",\n        \"nutritional_value\": \"350 calories, 5g protein, 10g fat, 50g carbohydrates\"\n      }\n    ],\n    \"Lunch\": [\n      {\n        \"meal\": \"Mixed vegetable soup with whole wheat bread\",\n        \"nutritional_value\": \"400 calories, 10g protein, 5g fat, 60g carbohydrates\"\n      }\n    ],\n    \"Dinner\": [\n      {\n        \"meal\": \"Palak paneer with brown rice and naan\",\n        \"nutritional_value\": \"650 calories, 25g protein, 20g fat, 90g carbohydrates\"\n      }\n    ]\n  },\n  \"Wednesday\": {\n    \"Breakfast\": [\n      {\n        \"meal\": \"Yogurt parfait with granola and mixed berries\",\n        \"nutritional_value\": \"300 calories, 10g protein, 5g fat, 40g carbohydrates\"\n      }\n    ],\n    \"Lunch\": [\n      {\n        \"meal\": \"Veggie wrap with hummus and mixed greens\",\n        \"nutritional_value\": \"500 calories, 15g protein, 10g fat, 70g carbohydrates\"\n      }\n    ],\n    \"Dinner\": [\n      {\n        \"meal\": \"Soybean curry with brown rice and mixed vegetables\",\n        \"nutritional_value\": \"600 calories, 20g protein, 15g fat, 80g carbohydrates\"\n      }\n    ]\n  },\n  \"Thursday\": {\n    \"Breakfast\": [\n      {\n        \"meal\": \"Smoothie bowl with banana and almond milk\",\n        \"nutritional_value\": \"350 calories, 5g protein, 10g fat, 50g carbohydrates\"\n      }\n    ],\n    \"Lunch\": [\n      {\n        \"meal\": \"Veggie stir-fry with brown rice and tofu\",\n        \"nutritional_value\": \"500 calories, 20g protein, 10g fat, 70g carbohydrates\"\n      }\n    ],\n    \"Dinner\": [\n      {\n        \"meal\": \"Veggie lasagna with whole wheat pasta and garlic bread\",\n        \"nutritional_value\": \"700 calories, 25g protein, 20g fat, 100g carbohydrates\"\n      }\n    ]\n  },\n  \"Friday\": {\n    \"Breakfast\": [\n      {\n        \"meal\": \"Avocado toast with whole wheat bread and scrambled tofu\",\n        \"nutritional_value\": \"400 calories, 15g protein, 15g fat, 60g carbohydrates\"\n      }\n    ],\n    \"Lunch\": [\n      {\n        \"meal\": \"Veggie quinoa bowl with mixed vegetables and lemon vinaigrette\",\n        \"nutritional_value\": \"550 calories, 20g protein, 10g fat, 80g carbohydrates\"\n      }\n    ],\n    \"Dinner\": [\n      {\n        \"meal\": \"Chickpea curry with brown rice and mixed vegetables\",\n        \"nutritional_value\": \"650 calories, 25g protein, 20g fat, 90g carbohydrates\"\n      }\n    ]\n  },\n  \"Saturday\": {\n    \"Breakfast\": [\n      {\n        \"meal\": \"Whole wheat waffles with mixed berries and coconut whipped cream\",\n        \"nutritional_value\": \"400 calories, 10g protein, 10g fat, 60g carbohydrates\"\n      }\n    ],\n    \"Lunch\": [\n      {\n        \"meal\": \"Veggie samosas with mint chutney and mixed greens\",\n        \"nutritional_value\": \"500 calories, 15g protein, 10g fat, 70g carbohydrates\"\n      }\n    ],\n    \"Dinner\": [\n      {\n        \"meal\": \"Veggie biryani with whole wheat naan and mixed vegetables\",\n        \"nutritional_value\": \"700 calories,  ...
